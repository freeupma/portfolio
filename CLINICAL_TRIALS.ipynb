# %% [markdown]
# <a href="https://colab.research.google.com/github/freeupma/portfolio/blob/main/CLINICAL_TRIALS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import glob

# Path to the directory containing your CSV files
csv_directory = '/content/drive/MyDrive/DTE'

# List all CSV files in the directory

# The global module searches for files that match a specific file pattern/name

# It can be used to search CSV files and for text in files.
csv_files = glob.glob(f'{csv_directory}/*.csv')

# Initialize an empty list to store individual dataframes
dfs = []

# Read each CSV file and append it to the list
for csv_file in csv_files:
    df = pd.read_csv(csv_file)
    dfs.append(df)

# Concatenate all dataframes into one
# If True, do not use the index values along the concatenation axis
# The resulting axis will be labeled 0, …, n - 1
combined_df = pd.concat(dfs, ignore_index=True)

# Save the combined dataframe to a new CSV file
combined_df.to_csv('combined_file.csv', index=False)

print('CSV files combined successfully and saved as combined_file.csv')
# Out:
# CSV files combined successfully and saved as combined_file.csv

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
combined_df.head()
# Out:
#     NCT Number                                        Study Title  \
# 0  NCT04614025  Open-label Multicenter Study to Evaluate the E...
# 1  NCT04646525  The Relationship Between Covid-19 Infection in...
# 2  NCT04333225  Hydroxychloroquine in the Prevention of COVID-...
# 3  NCT04996225  Effect of Aerobics and Balancing Exercises on ...
# 4  NCT04858425  Safety and Efficacy of Niclosamide in Patients...
#
#                                       Study URL    Acronym  \
# 0  https://clinicaltrials.gov/study/NCT04614025        NaN
# 1  https://clinicaltrials.gov/study/NCT04646525        NaN
# 2  https://clinicaltrials.gov/study/NCT04333225        NaN
# 3  https://clinicaltrials.gov/study/NCT04996225        NaN
# 4  https://clinicaltrials.gov/study/NCT04858425  RESERVOIR
#
#             Study Status                                      Brief Summary  \
# 0  ACTIVE_NOT_RECRUITING  This clinical trial will examine if a new trea...
# 1                UNKNOWN  We aimed to find out whether the tonsils and n...
# 2              COMPLETED  In order to assess the efficacy of hydroxychlo...
# 3              COMPLETED  The recently emerged coronavirus named Severe ...
# 4  ACTIVE_NOT_RECRUITING  This is a 2-part, 2-arm, Phase 2 , multicentre...
#
#   Study Results                                         Conditions  \
# 0            NO                                         COVID|ARDS
# 1            NO  Covid19|Immune Deficiency|Tonsillitis|Tonsil H...
# 2           YES                                           COVID-19
# 3            NO                             Corona Virus Infection
# 4            NO                                            Covid19
#
#                                   Interventions  \
# 0                           BIOLOGICAL: PLX-PAD
# 1         DIAGNOSTIC_TEST: Physical examination
# 2                      DRUG: Hydroxychloroquine
# 3  OTHER: Aerobics exercises, Balance exercises
# 4               DRUG: Niclosamide|DRUG: Placebo
#
#                             Primary Outcome Measures  ...  \
# 0            Number of ventilator-free days, 28 days  ...
# 1  The primary outcome of our study was the evalu...  ...
# 2  Number of Participants Infected With COVID-19 ...  ...
# 3  SPSS for Windows, version 22 (SPSS Inc., Chica...  ...
# 4  SAEs, Serious adverse event (SAE) coded by Sys...  ...
#
#                                         Study Design       Other IDs  \
# 0  Allocation: RANDOMIZED|Intervention Model: PAR...      PLX-COV-03
# 1          Observational Model: |Time Perspective: p        2020/480
# 2  Allocation: NON_RANDOMIZED|Intervention Model:...         020-132
# 3  Allocation: RANDOMIZED|Intervention Model: PAR...  A,B E COVID 19
# 4  Allocation: RANDOMIZED|Intervention Model: PAR...   AZ-NICL-COV-1
#
#    Start Date Primary Completion Date Completion Date First Posted  \
# 0  2020-10-19              2021-08-04         2023-01   2020-11-03
# 1  2020-10-01              2021-02-01      2021-02-01   2020-11-30
# 2  2020-04-03              2020-06-30      2020-06-30   2020-04-03
# 3  2021-08-01              2022-10-25      2023-02-10   2021-08-09
# 4  2021-04-30              2022-06-04         2023-05   2021-04-26
#
#   Results First Posted  Last Update Posted  \
# 0                  NaN          2022-12-21
# 1                  NaN          2020-11-30
# 2           2021-08-02          2021-08-20
# 3                  NaN          2023-02-22
# 4                  NaN          2023-04-06
#
#                                            Locations  \
# 0  Charite Campus Virchow, Berlin, 10117, Germany...
# 1  Selcuk University, Konya, Selcuklu, 42100, Turkey
# 2  Baylor University Medical Center, Dallas, Texa...
# 3                   Ahmed.Assem, Sohag, 82951, Egypt
# 4  Central Alabama Research, Birmingham, Alabama,...
#
#                             Study Documents
# 0                                       NaN
# 1                                       NaN
# 2  Study Protocol|Statistical Analysis Plan
# 3                                       NaN
# 4                                       NaN
#
# [5 rows x 30 columns]

# %%
combined_df.shape
# Out:
# (161863, 30)

# %%
combined_df.columns
# Out:
# Index(['NCT Number', 'Study Title', 'Study URL', 'Acronym', 'Study Status',
#        'Brief Summary', 'Study Results', 'Conditions', 'Interventions',
#        'Primary Outcome Measures', 'Secondary Outcome Measures',
#        'Other Outcome Measures', 'Sponsor', 'Collaborators', 'Sex', 'Age',
#        'Phases', 'Enrollment', 'Funder Type', 'Study Type', 'Study Design',
#        'Other IDs', 'Start Date', 'Primary Completion Date', 'Completion Date',
#        'First Posted', 'Results First Posted', 'Last Update Posted',
#        'Locations', 'Study Documents'],
#       dtype='object')

# %%
# Replace spaces with underscores in column names
combined_df.columns = combined_df.columns.str.replace(' ', '_')
combined_df.head(2)
# Out:
#     NCT_Number                                        Study_Title  \
# 0  NCT04614025  Open-label Multicenter Study to Evaluate the E...
# 1  NCT04646525  The Relationship Between Covid-19 Infection in...
#
#                                       Study_URL Acronym  \
# 0  https://clinicaltrials.gov/study/NCT04614025     NaN
# 1  https://clinicaltrials.gov/study/NCT04646525     NaN
#
#             Study_Status                                      Brief_Summary  \
# 0  ACTIVE_NOT_RECRUITING  This clinical trial will examine if a new trea...
# 1                UNKNOWN  We aimed to find out whether the tonsils and n...
#
#   Study_Results                                         Conditions  \
# 0            NO                                         COVID|ARDS
# 1            NO  Covid19|Immune Deficiency|Tonsillitis|Tonsil H...
#
#                            Interventions  \
# 0                    BIOLOGICAL: PLX-PAD
# 1  DIAGNOSTIC_TEST: Physical examination
#
#                             Primary_Outcome_Measures  ...  \
# 0            Number of ventilator-free days, 28 days  ...
# 1  The primary outcome of our study was the evalu...  ...
#
#                                         Study_Design   Other_IDs  Start_Date  \
# 0  Allocation: RANDOMIZED|Intervention Model: PAR...  PLX-COV-03  2020-10-19
# 1          Observational Model: |Time Perspective: p    2020/480  2020-10-01
#
#   Primary_Completion_Date Completion_Date First_Posted Results_First_Posted  \
# 0              2021-08-04         2023-01   2020-11-03                  NaN
# 1              2021-02-01      2021-02-01   2020-11-30                  NaN
#
#    Last_Update_Posted                                          Locations  \
# 0          2022-12-21  Charite Campus Virchow, Berlin, 10117, Germany...
# 1          2020-11-30  Selcuk University, Konya, Selcuklu, 42100, Turkey
#
#   Study_Documents
# 0             NaN
# 1             NaN
#
# [2 rows x 30 columns]

# %%
#find unique values and their counts
unique_values = combined_df['Study_Results'].value_counts()

# Print unique values and their counts
for value, count in unique_values.items():
    print(f'Value: {value}, Count: {count}')
# Out:
# Value: NO, Count: 142050
# Value: YES, Count: 19813

# %%
#check to ensure all columns are in the right data types.
combined_df.dtypes
# Out:
# NCT_Number                     object
# Study_Title                    object
# Study_URL                      object
# Acronym                        object
# Study_Status                   object
# Brief_Summary                  object
# Study_Results                  object
# Conditions                     object
# Interventions                  object
# Primary_Outcome_Measures       object
# Secondary_Outcome_Measures     object
# Other_Outcome_Measures         object
# Sponsor                        object
# Collaborators                  object
# Sex                            object
# Age                            object
# Phases                         object
# Enrollment                    float64
# Funder_Type                    object
# Study_Type                     object
# Study_Design                   object
# Other_IDs                      object
# Start_Date                     object
# Primary_Completion_Date        object
# Completion_Date                object
# First_Posted                   object
# Results_First_Posted           object
# Last_Update_Posted             object
# Locations                      object
# Study_Documents                object
# dtype: object
